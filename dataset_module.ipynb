# %%
from sklearn.datasets import load_breast_cancer

# %%
data = load_breast_cancer()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 data = load_breast_cancer(frame = True)
#
# File d:\ML basics\myenv\Lib\site-packages\sklearn\utils\_param_validation.py:196, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
# --> 196 params = func_sig.bind(*args, **kwargs)
#     197 params.apply_defaults()
#     199 # ignore self/cls and positional/keyword markers
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\inspect.py:3236, in Signature.bind(self, *args, **kwargs)
#    3231 def bind(self, /, *args, **kwargs):
#    3232     """Get a BoundArguments object, that maps the passed `args`
#    3233     and `kwargs` to the function's signature.  Raises `TypeError`
#    3234     if the passed arguments can not be bound.
# ...

# %%
dataset = data.frame()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 dataset = data.frame()
#
# TypeError: 'NoneType' object is not callable

# %%
dataset.head()
