# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# %%
X , y = load_iris(return_X_y = True)

# data  = load_iris()

# A , B = data.data , data.target

# %%
split = StratifiedShuffleSplit(n_splits = 1 , test_size = 0.2)

for test_idx , train_idx in split.split(X,y):
    X_train , X_test = X[train_idx] , X[test_idx]
    y_train , y_test = y[train_idx] , y[test_idx]

# %%
import matplotlib as plt
import numpy as np

count = np.bincount(X_train)
position = np.arange(3)

plt.bar(count , position)
plt.xticks(position , data.target_name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 4
#       1 import matplotlib as plt
#       2 import numpy as np
#       3
# ----> 4 count = np.bincount(X_train)
#       5 position = np.arange(3)
#       6
#       7 plt.bar(count , position)
#
# ValueError: object too deep for desired array
